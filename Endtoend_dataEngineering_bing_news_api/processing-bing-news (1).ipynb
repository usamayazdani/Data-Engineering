# %% [markdown]
# ### **Data Loading **

# %%
df = spark.read.option("multiline", "true").json("Files/bing-latest-news.json")
# df now is a Spark DataFrame containing JSON data from "Files/bing-latest-news.json".
display(df)
# Out:
# StatementMeta(, , , Waiting, , Waiting)
# SynapseWidget(Synapse.DataFrame, 61cd5a32-5db9-4888-a43b-4b4119721f76)

# %%
df=df.select("value")   #selecting the column which is realted to us and droping all other
# Out:
# StatementMeta(, , , Waiting, , Waiting)

# %%
display(df)
print(type(df))
print(df.printSchema())
# Out:
# StatementMeta(, , , Waiting, , Waiting)
# SynapseWidget(Synapse.DataFrame, 2ff005c6-168f-4628-9d44-7ce720c36a03)
# <class 'pyspark.sql.dataframe.DataFrame'>
# root
#  |-- value: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- about: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- name: string (nullable = true)
#  |    |    |    |    |-- readLink: string (nullable = true)
#  |    |    |-- category: string (nullable = true)
#  |    |    |-- datePublished: string (nullable = true)
#  |    |    |-- description: string (nullable = true)
#  |    |    |-- image: struct (nullable = true)
#  |    |    |    |-- thumbnail: struct (nullable = true)
#  |    |    |    |    |-- contentUrl: string (nullable = true)
#  |    |    |    |    |-- height: long (nullable = true)
#  |    |    |    |    |-- width: long (nullable = true)
#  |    |    |-- name: string (nullable = true)
#  |    |    |-- provider: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- _type: string (nullable = true)
#  |    |    |    |    |-- image: struct (nullable = true)
#  |    |    |    |    |    |-- thumbnail: struct (nullable = true)
#  |    |    |    |    |    |    |-- contentUrl: string (nullable = true)
#  |    |    |    |    |-- name: string (nullable = true)
#  |    |    |-- url: string (nullable = true)
#  |    |    |-- video: struct (nullable = true)
#  |    |    |    |-- name: string (nullable = true)
#  |    |    |    |-- thumbnail: struct (nullable = true)
#  |    |    |    |    |-- height: long (nullable = true)
#  |    |    |    |    |-- width: long (nullable = true)
#  |    |    |    |-- thumbnailUrl: string (nullable = true)
#
# None

# %%
#flatten nested object ...after each row will contain single json object
from pyspark.sql.functions import explode 
df_exploaded=df.select(explode(df["value"]).alias("json_object"))
# Out:
# StatementMeta(, , , Waiting, , Waiting)

# %%
display(df_exploaded)
# Out:
# StatementMeta(, , , Waiting, , Waiting)
# SynapseWidget(Synapse.DataFrame, 958fbda9-58a6-4c35-9625-de030b03336e)

# %%
# Convert DataFrame rows to JSON strings
json_list=df_exploaded.toJSON().collect()   #collect bring data from spark cluster to local environment
# Out:
# StatementMeta(, , , Waiting, , Waiting)

# %%
json_list
# Out:
# StatementMeta(, , , Waiting, , Waiting)
# ['{"json_object":{"about":[{"name":"Verenigde Staten","readLink":"https://api.bing.microsoft.com/api/v7/entities/5232ed96-85b1-2edb-12c6-63e6c597a1de"},{"name":"Nicolás Maduro","readLink":"https://api.bing.microsoft.com/api/v7/entities/62dd568b-6165-618b-d9a8-240b52e23c2f"},{"name":"Florida","readLink":"https://api.bing.microsoft.com/api/v7/entities/5fece3f4-e8e8-4159-843e-f725a930ad50"},{"name":"CNN","readLink":"https://api.bing.microsoft.com/api/v7/entities/c4c637e5-f9cc-a3ed-3380-7152515e062e"},{"name":"Venezuela","readLink":"https://api.bing.microsoft.com/api/v7/entities/6dd1d7bd-393f-a467-12fa-e71f98cc00b9"}],"datePublished":"2024-09-02T17:03:00.0000000Z","description":"De Verenigde Staten hebben maandag het vliegtuig van de Venezolaanse president Nicolás Maduro in beslag genomen. De actie werd uitgevoerd omdat de koop van het vliegtuig in strijd zou zijn met Amerika","image":{"thumbnail":{"contentUrl":"https://www.bing.com/th?id=OVFT.ty6YVUSXp2W8YSD0m6AHpC&pid=News","height":393,"width":700}},"name":"VS neemt vliegtuig van Venezolaanse president Maduro in beslag","provider":[{"_type":"Organization","image":{"thumbnail":{"contentUrl":"https://www.bing.com/th?id=ODF.yMPhwEVs3xY6mzNtAwHtDQ&pid=news"}},"name":"NU"}],"url":"https://www.nu.nl/buitenland/6326795/vs-neemt-vliegtuig-van-venezolaanse-president-maduro-in-beslag.html"}}',
#  '{"json_object":{"about":[{"name":"Oekraïne","readLink":"https://api.bing.microsoft.com/api/v7/entities/ad599477-9e6d-4a0e-bab5-0edf9db7115a"},{"name":"Volodymyr Zelensky","readLink":"https://api.bing.microsoft.com/api/v7/entities/9bae3411-f7b7-35a0-00a8-57f94c361da9"}],"datePublished":"2024-09-01T23:00:00.0000000Z","description":"Bijna wekelijks wordt Oekraïne opgeschrikt door corruptieschandalen. De bevolking is er inmiddels aan gewend. Onder druk van het Westen pakt de regering het probleem aan, maar de resultaten zijn mager","image":{"thumbnail":{"contentUrl":"https://www.bing.com/th?id=OVFT.Czg0_w9NZ6YESgWoC7OGPC&pid=News","height":367,"width":700}},"name":"Corruptie in Oekraïne is hardnekkig: ‘Soldaten vragen zich af waarom zij hun leven wagen voor zo’n staat’","provider":[{"_type":"Organization","name":"PAROOL"}],"url":"https://www.parool.nl/wereld/corruptie-in-oekraine-is-hardnekkig-soldaten-vragen-zich-af-waarom-zij-hun-leven-wagen-voor-zo-n-staat~b0f1b491/"}}',
#  '{"json_object":{"about":[{"name":"Bitcoin","readLink":"https://api.bing.microsoft.com/api/v7/entities/2d95ee9c-a8a0-d6fa-69b7-f6d996f0c946"}],"datePublished":"2024-09-02T08:06:00.0000000Z","description":"Bitcoin (BTC) heeft zijn gevreesde septembermaand in stijl afgetrapt. De bitcoin koers heeft rond middernacht namelijk een scherpe daling gemaakt tot zijn laagste prijs in meer dan twee weken van iets meer dan $57.000. Dit heeft ook de rest van de markt ...","image":{"thumbnail":{"contentUrl":"https://www.bing.com/th?id=OVFT.Gyv9-DKcVr7fYY5xDubZgC&pid=News","height":399,"width":700}},"name":"Bitcoin maakt plotselinge koersval tot $57.000, memecoins bloeden hard","provider":[{"_type":"Organization","name":"crypto-insiders"}],"url":"https://www.crypto-insiders.nl/marktupdates/bitcoin-maakt-plotselinge-koersval-tot-57-000-memecoins-bloeden-hard/"}}',
#  '{"json_object":{"about":[{"name":"Max Verstappen","readLink":"https://api.bing.microsoft.com/api/v7/entities/d2a3aa4d-dc3d-18cf-4d28-bab4616ad099"},{"name":"Grand Prix-wegrace van Italië","readLink":"https://api.bing.microsoft.com/api/v7/entities/17aa1ae5-7b0d-8afb-e648-fa3403432b38"},{"name":"Red Bull","readLink":"https://api.bing.microsoft.com/api/v7/entities/7cdd43fc-fd27-f4fe-fd82-156d98451ff2"},{"name":"Sergio Pérez","readLink":"https://api.bing.microsoft.com/api/v7/entities/f109cfb9-afd7-0044-f27c-3014698c1be7"}],"datePublished":"2024-09-01T18:00:00.0000000Z","description":"Max Verstappen kwam niet verder dan de zesde plaats in de Grand Prix van Italië. De Nederlander legt na afloop een duidelijke eis neer: updates.","image":{"thumbnail":{"contentUrl":"https://www.bing.com/th?id=OVFT._y36WaMCNE-f8X5EwMfwAC&pid=News","height":367,"width":700}},"name":"Verstappen eist updates voor \'monsterlijke\' auto","provider":[{"_type":"Organization","image":{"thumbnail":{"contentUrl":"https://www.bing.com/th?id=ODF.9Vc4lQG-yNR62QhWP0y6GA&pid=news"}},"name":"https//racingnews365.nl"}],"url":"https://racingnews365.nl/verstappen-eist-updates-voor-monsterlijke-auto"}}',
#  '{"json_object":{"about":[{"name":"Cardano","readLink":"https://api.bing.microsoft.com/api/v7/entities/da9934e6-219e-49b9-7839-ef01fb624a20"}],"datePublished":"2024-09-03T07:57:00.0000000Z","description":"September is historisch een rode maand voor de cryptomarkt, en ook dit jaar kleurden de meeste koersen rood in de eerste dagen van de maand. Toch was er","image":{"thumbnail":{"contentUrl":"https://www.bing.com/th?id=OVFT.0TUfa0253k_HuwOs6qwPQi&pid=News","height":399,"width":700}},"name":"Cardano start nieuw tijdperk met langverwachte, veelbelovende update","provider":[{"_type":"Organization","name":"crypto-insiders"}],"url":"https://www.crypto-insiders.nl/nieuws/cardano/cardano-start-nieuw-tijdperk-met-langverwachte-veelbelovende-update/"}}',
#  '{"json_object":{"about":[{"name":"Ferrari","readLink":"https://api.bing.microsoft.com/api/v7/entities/5578729a-73af-5f1a-9b3c-e468b44acfb4"},{"name":"Monza","readLink":"https://api.bing.microsoft.com/api/v7/entities/3e165c14-ee19-d6aa-38be-f2767c991703"},{"name":"Charles Leclerc","readLink":"https://api.bing.microsoft.com/api/v7/entities/77132433-16b0-2a3b-832b-e8efc636e4e4"},{"name":"La Gazzetta dello Sport","readLink":"https://api.bing.microsoft.com/api/v7/entities/ae846282-31fe-1d62-c0d8-571fccaf9e63"}],"datePublished":"2024-09-02T07:30:00.0000000Z","description":"Met een thuiszege van Ferrari op Monza, is het logische dat de Italiaanse kranten lyrisch zijn over de winst van Charles Leclerc. Tegelijkertijd zagen ze ook de worsteling van Verstappen die zich na d","image":{"thumbnail":{"contentUrl":"https://www.bing.com/th?id=OVFT.HsGTEZxTRq2KpVtDq3qQ2y&pid=News","height":367,"width":700}},"name":"Italiaanse media lyrisch over Ferrari-\'meesterwerk\', zien kannibaal Verstappen donderen","provider":[{"_type":"Organization","image":{"thumbnail":{"contentUrl":"https://www.bing.com/th?id=ODF.9Vc4lQG-yNR62QhWP0y6GA&pid=news"}},"name":"https//racingnews365.nl"}],"url":"https://racingnews365.nl/italiaanse-media-lyrisch-over-ferrari-meesterwerk-zien-kannibaal-verstappen-donderen"}}',
#  '{"json_object":{"about":[{"name":"Liverpool","readLink":"https://api.bing.microsoft.com/api/v7/entities/a5642e81-20ab-a561-17cc-52a63926b210"},{"name":"Virgil van Dijk","readLink":"https://api.bing.microsoft.com/api/v7/entities/2a6b66f7-a08d-f08f-fccb-a729b40eaae7"},{"name":"Arne Slot","readLink":"https://api.bing.microsoft.com/api/v7/entities/486f7116-76a2-6b5f-b011-99872e3824a1"},{"name":"Manchester United FC","readLink":"https://api.bing.microsoft.com/api/v7/entities/064ce28e-ed07-a026-2f79-1b321d7548ea"},{"name":"Ronald Koeman","readLink":"https://api.bing.microsoft.com/api/v7/entities/21c70a87-5dfa-860e-2304-b5aad0559397"},{"name":"Erik ten Hag","readLink":"https://api.bing.microsoft.com/api/v7/entities/a61e1753-9864-40c2-8860-7a57dde78c3a"},{"name":"De Telegraaf","readLink":"https://api.bing.microsoft.com/api/v7/entities/9d35a5f9-d594-d398-1e17-b30ade9d7385"},{"name":"Mohamed Salah","readLink":"https://api.bing.microsoft.com/api/v7/entities/fbd8133b-7464-418f-a557-67bfb2281bbd"}],"datePublished":"2024-09-02T04:42:00.0000000Z","description":"Liverpool won zondag met 3-0 van Manchester United. Een perfecte eerste topwedstrijd voor Arne Slot. Met zijn spel \'wijst hij ook bondscoach","image":{"thumbnail":{"contentUrl":"https://www.bing.com/th?id=OVFT.g6D2MxUJPKvp5hyjSs6p6C&pid=News","height":466,"width":700}},"name":"\'Ingekakte vedettes bloeien op bij Liverpool: Virgil van Dijk doet onder Arne Slot wat hij bij Oranje naliet\'","provider":[{"_type":"Organization","image":{"thumbnail":{"contentUrl":"https://www.bing.com/th?id=ODF.zf-iih5ikk6IWEmvgf_wIQ&pid=news"}},"name":"sportnieuws"}],"url":"https://sportnieuws.nl/voetbal/nieuws/ingekakte-vedettes-bloeien-op-bij-liverpool-virgil-van-dijk-doet-onder-arne-slot-wat-hij-bij-oranje-naliet-2024090204170011136/"}}',
#  '{"json_object":{"about":[{"name":"Meghan Markle","readLink":"https://api.bing.microsoft.com/api/v7/entities/e4308957-a185-03fa-10ed-3c7b47fd0aea"},{"name":"Colombia","readLink":"https://api.bing.microsoft.com/api/v7/entities/c396e3d8-2a85-d230-f691-7850536d840e"}],"datePublished":"2024-09-02T10:01:00.0000000Z","description":"Vier dagen in Colombia met de Sussexes gaven mij een kijkje in de keuken – zo werken ze en dit is voor wie ze het allemaal doen","image":{"thumbnail":{"contentUrl":"https://www.bing.com/th?id=OVFT.pjaDm4-ZDNP9nDKX-eRiFi&pid=News","height":353,"width":700}},"name":"Wat ik heb geleerd van het reizen met prins Harry en Meghan Markle","provider":[{"_type":"Organization","image":{"thumbnail":{"contentUrl":"https://www.bing.com/th?id=ODF.6hZHTPdJ16H2eaatpRcgLw&pid=news"}},"name":"ELLE"}],"url":"https://www.elle.com/nl/lifestyle/lifestyle-nieuws/a62031747/prince-harry-meghan-markle-colombia-reis-2024/","video":{"name":"Wat ik heb geleerd van het reizen met prins Harry en Meghan Markle","thumbnail":{"height":262,"width":520},"thumbnailUrl":"https://www.bing.com/th?id=OVF.BJIaOlKx6t%2F0OJppCHJ7vg&pid=News"}}}',
#  '{"json_object":{"about":[{"name":"Atos","readLink":"https://api.bing.microsoft.com/api/v7/entities/c759f83c-9be9-cad7-2f25-d8bcee2e879b"}],"category":"Business","datePublished":"2024-09-02T07:09:00.0000000Z","description":"Atos voorziet inmiddels een omzetdaling van 4,0 procent tot 9,7 miljard euro dit jaar, waar eerder nog op 9,8 miljard euro werd gerekend. De operationele marge zal niet op 2,9 procent, maar op 2,4 procent uitkomen.","image":{"thumbnail":{"contentUrl":"https://www.bing.com/th?id=OVFT.Wk5O3c2TzzqplBDKkKQ8YC&pid=News","height":700,"width":466}},"name":"Update: Atos rekent op minder omzet","provider":[{"_type":"Organization","image":{"thumbnail":{"contentUrl":"https://www.bing.com/th?id=ODF.iU_nC4vZWkcUVEzJ9Hr5ww&pid=news"}},"name":"deaandeelhouder.nl"}],"url":"https://www.deaandeelhouder.nl/nieuws/2024/09/02/update-atos-rekent-op-minder-omzet/"}}',
#  '{"json_object":{"about":[{"name":"Atos","readLink":"https://api.bing.microsoft.com/api/v7/entities/c759f83c-9be9-cad7-2f25-d8bcee2e879b"}],"category":"Business","datePublished":"2024-09-03T09:05:00.0000000Z","description":"Voor 2024 verwacht Atos een iets lagere omzet en een verminderde operationele marge in vergelijking met eerdere prognoses. Dit wordt toegeschreven aan een","image":{"thumbnail":{"contentUrl":"https://www.bing.com/th?id=OVFT.JvRqGf7OngGL7XUY_KkPOC&pid=News","height":365,"width":700}},"name":"Atos past financiële verwachtingen aan","provider":[{"_type":"Organization","name":"Knack"}],"url":"https://datanews.knack.be/nieuws/bedrijven/financieel/atos-past-financiele-verwachtingen-aan/"}}']

# %%
#convert different item into json dictionary and load them into list
import json

title = []
description = []
category = []
url = []
image = []
provider = []
datePublished = []

for counter_str in json_list:
    try:
        news_json = json.loads(counter_str) #load json into dictionay 
        # no processing if the json from api does not contain category or image
        if(not news_json['json_object'].get("category") is None and not news_json['json_object'].get('image') is None):
            title.append(news_json['json_object']['name'])
            description.append(news_json['json_object']['description'])
            category.append(news_json['json_object']['category'])
            url.append(news_json['json_object']['url'])
            image.append(news_json['json_object']['image']['thumbnail']['contentUrl'])
            provider.append(news_json['json_object']['provider'][0]['name'])
            datePublished.append(news_json['json_object']['datePublished'])
    except Exception as e:
        print(f"errors processing json: {e}")
# Out:
# StatementMeta(, , , Waiting, , Waiting)

# %%
datePublished
# Out:
# StatementMeta(, , , Waiting, , Waiting)
# ['2024-09-02T07:09:00.0000000Z', '2024-09-03T09:05:00.0000000Z']

# %%
from pyspark.sql.types import StructType,StructField, StringType,TimestampType

data = list(zip(title,description,category,url,image,provider,datePublished))

schema = StructType([
    StructField("title", StringType(), True),
    StructField("description", StringType(), True),
    StructField("category", StringType(), True),
    StructField("url", StringType(), True),
    StructField("image", StringType(), True),
    StructField("provider", StringType(), True),
    StructField("datePublished", StringType(), True)
    ])

df_cleaned = spark.createDataFrame(data,schema =schema)
# Out:
# StatementMeta(, , , Waiting, , Waiting)

# %%
from pyspark.sql.functions import to_date, date_format
df_cleaned_final = df_cleaned.withColumn("datePublished", date_format(to_date("datePublished"), "dd-MM-yyyy"))
# Out:
# StatementMeta(, , , Waiting, , Waiting)

# %%
from pyspark.sql.utils import AnalysisException

table_name = "bing_lake_db.tbl_latest_news"

try: 
    df_cleaned_final.write.format("delta").saveAsTable(table_name)

except AnalysisException:
    print ("Table already exists!")

    df_cleaned_final.createOrReplaceTempView("vw_df_cleaned_final")
    # check if the url matched between the source and the target, if it matched then, check if any of the 
    # column values has changed and update the whole row accordingly, if not insert the whole row in the table
    spark.sql(f"""MERGE INTO {table_name} target_table
                     USING vw_df_cleaned_final source_view
                     ON source_view.url = target_table.url

                     WHEN MATCHED AND
                     (source_view.title <> target_table.title OR
                     source_view.description <> target_table.description OR
                     source_view.category <> target_table.category OR
                     source_view.image <> target_table.image OR
                     source_view.provider <> target_table.provider OR
                     source_view.datePublished <> target_table.datePublished)

                     THEN UPDATE SET *
                     WHEN NOT MATCHED THEN INSERT *

                """)
# Out:
# StatementMeta(, , , Waiting, , Waiting)

# %%
df=spark.sql("SELECT * FROM bing_lake_db.tbl_latest_news")
# Out:
# StatementMeta(, , , Waiting, , Waiting)

# %%
df
# Out:
# StatementMeta(, , , Waiting, , Waiting)
# DataFrame[title: string, description: string, category: string, url: string, image: string, provider: string, datePublished: string]

# %%
# from pyspark.sql.functions import col,to_date 
# df=df.withColumn("datePublished",to_date(col("datePublished"),"dd-MMM-yyyy"))
# Out:
# StatementMeta(, , , Waiting, , Waiting)

# %%
display(df)
# Out:
# StatementMeta(, , , Waiting, , Waiting)
# SynapseWidget(Synapse.DataFrame, 6d3081f0-d2da-44ff-b80a-d2c9ef776673)

# %%
df.printSchema()
# Out:
# StatementMeta(, , , Waiting, , Waiting)
# root
#  |-- title: string (nullable = true)
#  |-- description: string (nullable = true)
#  |-- category: string (nullable = true)
#  |-- url: string (nullable = true)
#  |-- image: string (nullable = true)
#  |-- provider: string (nullable = true)
#  |-- datePublished: string (nullable = true)

# %%
# df.write.format('delta').mode("overwrite").option("overwriteSchema","True").saveAsTable(table_name)
# Out:
# StatementMeta(, , , Waiting, , Waiting)

# %%
# from pyspark.sql.functions import date_format

# # Format the 'datePublished' column as 'dd-MM-yyyy'
# df_cleaned_final = df_cleaned.withColumn("datePublished", date_format("datePublished", "dd-MM-yyyy"))

# # Show the result
# Out:
# StatementMeta(, , , Waiting, , Waiting)
